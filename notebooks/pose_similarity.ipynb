# %%
from tqdm import tqdm
import numpy as np
from rdkit import Chem
from rdkit.Chem import rdFingerprintGenerator
from rdkit import DataStructs
from rdkit.ML.Cluster import Butina
import pandas as pd
import time

# %%
ligands_df = pd.read_csv("/home/luca/projects/2026_filterfiesta_debugging/filterfiesta/notebooks/cluster_test.smi", sep=" ")
ligands_smi = ligands_df[ligands_df.columns[0]]

#print(ligands_df)
#print(ligands_smi)
#print(ligands_smi[0])

ligands = [Chem.MolFromSmiles(smi) for smi in ligands_smi]

# %%
import multiprocessing as mp
import os

print("start method:", mp.get_start_method())
print("cpu_count():", os.cpu_count())
print("sched_getaffinity:", len(os.sched_getaffinity(0)))  # respects cgroup/SLURM limits
# Out:
# start method: fork
# cpu_count(): 20
# sched_getaffinity: 20

# %%
def _compute_row(i, fingerprints, cutoff):
    """Worker function: compute neighbor matches for index i against
    fingerprints[:i]. Pure function - no shared state touched, so this
    is safe to run in a separate process. Returns (i, matched_positions)
    so the caller can always tell which row a result belongs to,
    regardless of the order results come back in."""
    similarities = np.asarray(
        DataStructs.BulkTanimotoSimilarity(fingerprints[i], fingerprints[:i])
    )
    distances = 1 - similarities
    matched = np.nonzero(distances <= cutoff)[0]
    return i, matched.tolist()


def zigzag_order(n):
    """Interleave small and large i values (1, n-1, 2, n-2, ...) so that
    consecutive tasks - and therefore chunks built from consecutive
    tasks - have roughly constant total cost, instead of ascending order
    which puts all the cheap tasks first and all the expensive tasks last."""
    order = []
    lo, hi = 1, n - 1
    while lo <= hi:
        order.append(lo)
        if hi != lo:
            order.append(hi)
        lo += 1
        hi -= 1
    return order


def calculate_neighbors_parallel(self, cutoff, n_workers=None, chunksize=None):
    """Parallel neighbor counting for self.morgan_fingerprints, equivalent
    to the sequential 'calculate number of neighbors for all molecules'
    block in NewClusterDajeDarko. Must run on the pristine, unpopped
    from_idx_to_fp (same precondition as the sequential version)."""
    fingerprints = self.morgan_fingerprints
    n = len(fingerprints)
    neighbor_counts = {i: 0 for i in range(n)}

    if n_workers is None:
        n_workers = len(os.sched_getaffinity(0)) if hasattr(os, "sched_getaffinity") else os.cpu_count()

    order = zigzag_order(n)

    if chunksize is None:
        # aim for ~20 chunks per worker, so the pool has room to balance
        # load even with the zig-zag ordering already smoothing things out
        chunksize = max(1, len(order) // (n_workers * 20))

    worker = partial(_compute_row, fingerprints=fingerprints, cutoff=cutoff)

    with Pool(processes=n_workers) as pool:
        for i, matched_positions in pool.imap_unordered(worker, order, chunksize=chunksize):
            neighbor_counts[i] += len(matched_positions)
            for j in matched_positions:
                neighbor_counts[j] += 1

    return neighbor_counts

# %%
def NewClusterDajeDarko(self, cutoff=0.2):
    '''New plan: be more like Darko.
    - Fingerprints are calculated and stored in memory
    - BulkTanimotoSimilarity is used to create a list/array of tuples: (molecule, number_of_neighbours)
    - List is sorted based on neighbours
    - First element: BulkTanimoto on every other element of the list --> if match, remove from list
    - Save first element as cluster centroid of cluster #1
    - Take the next available element and repeat BulkTanimoto --> gets faster each time
    - Profit
    '''
    start = time.time()

    cutoff = 0.3

    morgan_gen = rdFingerprintGenerator.GetMorganGenerator(radius=4, fpSize=1024) # !!! to separate into its own method
    print("Generating Morgan fingerprints...")
            #morgan_fingerprints = [morgan_gen.GetFingerprint(ligands[i]) for i in tqdm(scores["Supplier order"]) if ligands[i] is not None]
    from_idx_to_fp = {i:fp for i,fp in enumerate([morgan_gen.GetFingerprint(i) for i in ligands])}
    n = len(from_idx_to_fp)
    # from_idx_to_fp = {i:fp for i,fp in enumerate(morgan_fingerprints)}
    cluster_counter = 0
    # create arrays filled with 0s, to be later filled with cluster numbers and bools for cluster centroids
    cluster_number=np.zeros((n))
    cluster_centroid=np.zeros((n))

    # calculate number of neighbors for all molecules (only once as per Butina original implementation)
    from_idx_to_neighbors = {i:0 for i in from_idx_to_fp.keys()}

    from_idx_to_neighbors = calculate_neighbors_parallel(cutoff)

    # main loop: iteratively finds cluster centroids, assigns as cluster members all molecules within cutoff, then removes them from the dicts
    while len(from_idx_to_fp) > 0:
        print(f"Finding members for cluster {cluster_counter}...")

        # find centroid, i.e. molecule with the highest number of neighbours
        centroid_idx = list(from_idx_to_neighbors)[np.argmax(list(from_idx_to_neighbors.values()))]
        centroid_fp = from_idx_to_fp[centroid_idx]

        # remove centroid from dicts
        from_idx_to_fp.pop(centroid_idx)
        from_idx_to_neighbors.pop(centroid_idx)

        # find cluster members
        similarities = np.asarray(DataStructs.BulkTanimotoSimilarity(centroid_fp, list(from_idx_to_fp.values())))
        distances = 1 - similarities
        mask = distances <= cutoff

        # retrieve cluster member array using numpy fancy indexing
        cluster_members = np.asarray(list(from_idx_to_fp.keys()), dtype=int)[mask]

        # remove cluster members from dictionaries
        from_idx_to_fp = {key:from_idx_to_fp[key] for key in from_idx_to_fp.keys() if key not in set(cluster_members)}
        from_idx_to_neighbors = {key:from_idx_to_neighbors[key] for key in from_idx_to_fp.keys()}

        # update arrays with cluster members and cluster centroid
        cluster_number[cluster_members] = cluster_counter
        cluster_centroid[centroid_idx] = 1

        # increase cluster counter
        cluster_counter += 1

    print(f"Done. Found {len(np.nonzero(cluster_centroid)[0])} clusters")

    end = time.time()

    print("Cluster_number:\n", cluster_number)

    print("Time:",end - start)

# %%
# def NewClusterDajeDarko(cutoff=0.2):
'''New plan: be more like Darko.
- Fingerprints are calculated and stored in memory
- BulkTanimotoSimilarity is used to create a list/array of tuples: (molecule, number_of_neighbours)
- List is sorted based on neighbours
- First element: BulkTanimoto on every other element of the list --> if match, remove from list
- Save first element as cluster centroid of cluster #1
- Take the next available element and repeat BulkTanimoto --> gets faster each time
- Profit
'''
start = time.time()

cutoff = 0.3

morgan_gen = rdFingerprintGenerator.GetMorganGenerator(radius=4, fpSize=1024) # !!! to separate into its own method
print("Generating Morgan fingerprints...")
        #morgan_fingerprints = [morgan_gen.GetFingerprint(ligands[i]) for i in tqdm(scores["Supplier order"]) if ligands[i] is not None]
from_idx_to_fp = {i:fp for i,fp in enumerate([morgan_gen.GetFingerprint(i) for i in ligands])}
n = len(from_idx_to_fp)
# from_idx_to_fp = {i:fp for i,fp in enumerate(morgan_fingerprints)}
cluster_counter = 0
# create arrays filled with 0s, to be later filled with cluster numbers and bools for cluster centroids
cluster_number=np.zeros((n))
cluster_centroid=np.zeros((n))

# calculate number of neighbors for all molecules (only once as per Butina original implementation)
from_idx_to_neighbors = {i:0 for i in from_idx_to_fp.keys()}

print("Calculating neighbours...")
for i in tqdm(list(from_idx_to_neighbors.keys())[1:]):
    similarities = np.asarray(DataStructs.BulkTanimotoSimilarity(from_idx_to_fp[i], list(from_idx_to_fp.values())[:i]))
    distances = 1 - similarities  # identical arithmetic to the original code
    matched = np.nonzero(distances <= cutoff)[0]
    for j in matched:
        j = int(j)
        from_idx_to_neighbors[j] += 1
        from_idx_to_neighbors[i] += 1

# main loop: iteratively finds cluster centroids, assigns as cluster members all molecules within cutoff, then removes them from the dicts
while len(from_idx_to_fp) > 0:
    print(f"Finding members for cluster {cluster_counter}...")

    # find centroid, i.e. molecule with the highest number of neighbours
    centroid_idx = list(from_idx_to_neighbors)[np.argmax(list(from_idx_to_neighbors.values()))]
    centroid_fp = from_idx_to_fp[centroid_idx]

    # remove centroid from dicts
    from_idx_to_fp.pop(centroid_idx)
    from_idx_to_neighbors.pop(centroid_idx)

    # find cluster members
    similarities = np.asarray(DataStructs.BulkTanimotoSimilarity(centroid_fp, list(from_idx_to_fp.values())))
    distances = 1 - similarities
    mask = distances <= cutoff

    # retrieve cluster member array using numpy fancy indexing
    cluster_members = np.asarray(list(from_idx_to_fp.keys()), dtype=int)[mask]

    # remove cluster members from dictionaries
    from_idx_to_fp = {key:from_idx_to_fp[key] for key in from_idx_to_fp.keys() if key not in set(cluster_members)}
    from_idx_to_neighbors = {key:from_idx_to_neighbors[key] for key in from_idx_to_fp.keys()}

    # update arrays with cluster members and cluster centroid
    cluster_number[cluster_members] = cluster_counter
    cluster_centroid[centroid_idx] = 1

    # increase cluster counter
    cluster_counter += 1

print(f"Done. Found {len(np.nonzero(cluster_centroid)[0])} clusters")

end = time.time()

print("Cluster_number:\n", cluster_number)

print("Time:",end - start)

# %%
from multiprocessing import Pool
from functools import partial

def _compute_row(i, fingerprints, cutoff):
    """Compute neighbor matches for index i against fingerprints[:i].
    Returns (i, list_of_matched_js). Pure function, no shared state."""
    similarities = np.asarray(
        DataStructs.BulkTanimotoSimilarity(fingerprints[i], fingerprints[:i])
    )
    distances = 1 - similarities
    matched = np.nonzero(distances <= cutoff)[0]
    return i, matched.tolist()


def calculate_neighbors_parallel(from_idx_to_fp, cutoff, n_workers=None):
    # Snapshot into a single ordered list ONCE, so every worker slices
    # consistently by position, and we avoid the [:i] key/position bug
    # from your snippet above.
    indices = list(from_idx_to_fp.keys())
    fingerprints = [from_idx_to_fp[idx] for idx in indices]  # position -> fp
    idx_of_position = indices  # position -> original key

    from_idx_to_neighbors = {idx: 0 for idx in indices}

    worker = partial(_compute_row, fingerprints=fingerprints, cutoff=cutoff)

    with Pool(processes=n_workers) as pool:
        # imap keeps results in order and lets tqdm show progress;
        # chunksize>1 cuts IPC overhead since each task is short
        results = list(tqdm(
            pool.imap(worker, range(1, len(fingerprints)), chunksize=50),
            total=len(fingerprints) - 1
        ))

    # single-process accumulation: cheap, and avoids any race condition
    for position_i, matched_positions in results:
        real_i = idx_of_position[position_i]
        from_idx_to_neighbors[real_i] += len(matched_positions)
        for pos_j in matched_positions:
            real_j = idx_of_position[pos_j]
            from_idx_to_neighbors[real_j] += 1

    return from_idx_to_neighbors

# %%
prova = {'a':2, 'b':1, 'c':3}

print(list(prova))
array_prova = np.asarray(list(prova.values()))
print(array_prova)
massimo = np.argmax(array_prova)
print(massimo)

prova2 = [12,34,54,123]
print(prova2.index(34))
# Out:
# ['a', 'b', 'c']
# [2 1 3]
# 2
# 1

# %%
morgan_fingerprints = ["fp"+str(i) for i in range(500)]

n = len(morgan_fingerprints)
from_fp_to_neighbors = {i:0 for i in range(n)}

cluster_counter = 0
# create arrays filled with 0s, to be later filled with cluster numbers and bools for cluster centroids
cluster_number=np.zeros((n))
cluster_centroid=np.zeros((n))

while len(from_fp_to_neighbors) > 1:
    for i in from_fp_to_neighbors.keys():
        similarities = np.asarray(DataStructs.BulkTanimotoSimilarity(self.morgan_fingerprints[i], self.morgan_fingerprints[:i]))
        distances = 1 - similarities  # identical arithmetic to the original code
        matched = np.nonzero(distances <= cutoff)[0]
        for j in matched:
            j = int(j)
            from_fp_to_neighbors[j] += 1
            from_fp_to_neighbors[i] += 1

    centroid = from_fp_to_neighbors.pop(list(from_fp_to_neighbors)[np.argmax(from_fp_to_neighbors.values())])

    similarities = np.asarray(DataStructs.BulkTanimotoSimilarity(centroid, np.asarray(from_fp_to_neighbors)))
    distances = 1 - similarities

# %%
import pandas as pd
from rdkit.Chem import PandasTools
from rdkit.Chem.rdmolfiles import SDWriter
from rdkit import Chem
from rdkit.Chem import AllChem
from rdkit.Chem import SDMolSupplier
from rdkit import RDConfig
from rdkit.Geometry import Point3D
import numpy as np
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import pandas as pd
#       2 from rdkit.Chem import PandasTools
#       3 from rdkit.Chem.rdmolfiles import SDWriter
#
# ModuleNotFoundError: No module named 'pandas'

# %% [markdown]
# USING SDMolSupplier

# %%
# Input and output file path initialization

sdf_paths = ['..\\..\\..\\7-Docking HD score migliori\\240731_Top10PercentSelection\\2-fredHD_corretto\\OK_C1_Top10Percent_dockHD.sdf\\OK_C1_Top10Percent_dockHD.sdf',
         '..\\..\\..\\7-Docking HD score migliori\\240731_Top10PercentSelection\\2-fredHD_corretto\\OK_C2_Top10Percent_dockHD.sdf\\OK_C2_Top10Percent_dockHD.sdf',
         '..\\..\\..\\7-Docking HD score migliori\\240731_Top10PercentSelection\\2-fredHD_corretto\\OK_C3_Top10Percent_dockHD.sdf\\OK_C3_Top10Percent_dockHD.sdf',
         '..\\..\\..\\7-Docking HD score migliori\\240731_Top10PercentSelection\\2-fredHD_corretto\\OK_C4_Top10Percent_dockHD.sdf\\OK_C4_Top10Percent_dockHD.sdf']

mol_iniziali_sdf_paths = ["..\\..\\..\\6-Molecole iniziali ionizzate\\2-fred su omega 20\\ion_fred_pose_allstereo_HDcorretto_20\\OK_C1_pose_allstereo20_dockHD.sdf\\OK_C1_pose_allstereo20_dockHD.sdf",
                         "..\\..\\..\\6-Molecole iniziali ionizzate\\2-fred su omega 20\\ion_fred_pose_allstereo_HDcorretto_20\\OK_C4_pose_allstereo20_dockHD.sdf\\OK_C4_pose_allstereo20_dockHD.sdf"]

nuovo_sdf_paths = ["..\\..\\..\\7-Docking HD score migliori\\240731_Top10PercentSelection\\2-fredHD_corretto\\8HD8_Top10Percent_dockHD\\8HD8_Top10Percent_dockHD.sdf\\8HD8_Top10Percent_dockHD.sdf"]
nuovo20_sdf_paths = ["..\\..\\..\\6-Molecole iniziali ionizzate\\2-fred su omega 20\\ion_fred_pose_allstereo_HDcorretto_20\\8HD8_20_dockHD.sdf\\8HD8_20_dockHD.sdf"]

score_paths = ['..\\..\\..\\7-Docking HD score migliori\\240731_Top10PercentSelection\\2-fredHD_corretto\\OK_C1_Top10Percent_dockHD_score.txt',
         '..\\..\\..\\7-Docking HD score migliori\\240731_Top10PercentSelection\\2-fredHD_corretto\\OK_C2_Top10Percent_dockHD_score.txt',
         '..\\..\\..\\7-Docking HD score migliori\\240731_Top10PercentSelection\\2-fredHD_corretto\\OK_C3_Top10Percent_dockHD_score.txt',
         '..\\..\\..\\7-Docking HD score migliori\\240731_Top10PercentSelection\\2-fredHD_corretto\\OK_C4_Top10Percent_dockHD_score.txt']

mol_iniziali_score_paths = ["..\\..\\..\\6-Molecole iniziali ionizzate\\2-fred su omega 20\\ion_fred_pose_allstereo_HDcorretto_20\\OK_C1_pose_allstereo20_dockHD_score.txt",
                           "..\\..\\..\\6-Molecole iniziali ionizzate\\2-fred su omega 20\\ion_fred_pose_allstereo_HDcorretto_20\\OK_C4_pose_allstereo20_dockHD_score.txt"]

nuovo_score_paths = ["..\\..\\..\\7-Docking HD score migliori\\240731_Top10PercentSelection\\2-fredHD_corretto\\8HD8_Top10Percent_dockHD\\8HD8_Top10Percent_dockHD_score.txt"]
nuovo20_score_paths = ["..\\..\\..\\6-Molecole iniziali ionizzate\\2-fred su omega 20\\ion_fred_pose_allstereo_HDcorretto_20\\8HD8_20_dockHD_score.txt"]

where_to_save = "..\\..\\..\\8-Filtraggio\\pose_similarity\\BestPose_Top10_8HD8\\"

# Pose similarity calculation and file update

for n in range(len(nuovo20_score_paths)):


    # Dataframes initialization

    # Load .sdf file as pandas dataframe
    sdf_suppl = SDMolSupplier(nuovo20_sdf_paths[n])

    # Load score file as pandas dataframe
    score_frame = pd.read_csv(nuovo20_score_paths[n], sep='\t')


    # Average conformer structure calculation

    # Group the dataframe into chunks of 10 molecules (same molecule, different conformers)
    grouped = score_frame.groupby(score_frame.index // 10)

    mean_RMSD_tot = []
    best_poses = []
    sdf_writer = SDWriter(where_to_save + "C" + str(n+1) + "_8HD8_20dockHD_score_BestPose.sdf")

    for group_number, group in grouped:
        positions = []
        RMSD_group = []

        # Loop through the 10 conformers and collect atomic positions
        for i in range(10):
            mol = sdf_suppl[int(group.index[i])]  # Get the ith molecule (conformer)
            conf = mol.GetConformer()        # Get the conformer
            coord = np.array(conf.GetPositions())  # Get atomic positions as a numpy array
            positions.append(coord)

        # Calculate the average atomic positions across the 10 conformers
        average_pos = np.mean(positions, axis=0)

        # Now update each conformer's atom positions to the average position

        mol0 = sdf_suppl[int(group.index[0])]  # Get the first molecule (conformer), which by deafault has the highest score among the conformers
        sdf_writer.write(mol0) #add the highest scoring conformer to the .sdf writer

        # Create a deep copy of the molecule to avoid modifying the original
        mol2 = Chem.Mol(mol0)
        conf2 = mol2.GetConformer()  # Get the conformer for updating positions

        # Update each atom's position to the averaged position
        for m in range(conf2.GetNumAtoms()):
            x, y, z = average_pos[m]
            conf2.SetAtomPosition(m, Point3D(x, y, z))

        #
        for j in range(10):
            rmsd = AllChem.CalcRMS(sdf_suppl[int(group.index[j])], mol2)
            RMSD_group.append(rmsd)

        mean_RMSD = np.mean(RMSD_group)
        mean_RMSD_tot.append(mean_RMSD)

    # Dataframe formatting

    score_frame2 = pd.DataFrame(score_frame.loc[score_frame["Pose"] == 0]) # Docking scores dataframe
    score_frame2["Average RMSD"] = mean_RMSD_tot


    # Saving

    # Save updated score file
    score_frame2.to_csv(where_to_save + "C" + str(n+1) + "_8HD8_20dockHD_score_BestPose.txt", index=False)

# %% [markdown]
# USING PandasTools.LoadSDF

# %%
# Input and output file path initialization

sdf_paths = ['..\\..\\..\\..\\7-Docking HD score migliori\\240731_Top10PercentSelection\\2-fredHD_corretto\\OK_C1_Top10Percent_dockHD.sdf\\OK_C1_Top10Percent_dockHD.sdf',
         '..\\..\\..\\..\\7-Docking HD score migliori\\240731_Top10PercentSelection\\2-fredHD_corretto\\OK_C2_Top10Percent_dockHD.sdf\\OK_C2_Top10Percent_dockHD.sdf',
         '..\\..\\..\\..\\7-Docking HD score migliori\\240731_Top10PercentSelection\\2-fredHD_corretto\\OK_C3_Top10Percent_dockHD.sdf\\OK_C3_Top10Percent_dockHD.sdf',
         '..\\..\\..\\..\\7-Docking HD score migliori\\240731_Top10PercentSelection\\2-fredHD_corretto\\OK_C4_Top10Percent_dockHD.sdf\\OK_C4_Top10Percent_dockHD.sdf']

score_paths = ['..\\..\\..\\..\\7-Docking HD score migliori\\240731_Top10PercentSelection\\2-fredHD_corretto\\OK_C1_Top10Percent_dockHD_score.txt',
         '..\\..\\..\\..\\7-Docking HD score migliori\\240731_Top10PercentSelection\\2-fredHD_corretto\\OK_C2_Top10Percent_dockHD_score.txt',
         '..\\..\\..\\..\\7-Docking HD score migliori\\240731_Top10PercentSelection\\2-fredHD_corretto\\OK_C3_Top10Percent_dockHD_score.txt',
         '..\\..\\..\\..\\7-Docking HD score migliori\\240731_Top10PercentSelection\\2-fredHD_corretto\\OK_C4_Top10Percent_dockHD_score.txt']

where_to_save = "..\\..\\..\\..\\8-Filtraggio\\pose_similarity\\"


# Pose similarity calculation and file update

for n in range(len(sdf_paths)):


    # Dataframes initialization

    # Load .sdf file as pandas dataframe
    sdf_frame = PandasTools.LoadSDF(sdf_paths[n],smilesName='SMILES',molColName='Molecule',includeFingerprints=True)

    # Load score file as pandas dataframe
    score_frame = pd.read_csv(score_paths[n], sep='\t')


    # Average conformer structure calculation

    # Group the dataframe into chunks of 10 molecules (same molecule, different conformers)
    grouped = sdf_frame.groupby(sdf_frame.index // 10)

    mean_RMSD_tot = []

    for group_number, group in grouped:
        positions = []
        RMSD_group = []

        # Loop through the 10 conformers and collect atomic positions
        for i in range(10):
            mol = group["Molecule"].iloc[i]  # Get the ith molecule (conformer)
            conf = mol.GetConformer()        # Get the conformer
            coord = np.array(conf.GetPositions())  # Get atomic positions as a numpy array
            positions.append(coord)

        # Calculate the average atomic positions across the 10 conformers
        average_pos = np.mean(positions, axis=0)

        # Now update each conformer's atom positions to the average position

        mol0 = group["Molecule"].iloc[0]  # Get the first molecule (conformer)

        # Create a deep copy of the molecule to avoid modifying the original
        mol2 = Chem.Mol(mol0)
        conf2 = mol2.GetConformer()  # Get the conformer for updating positions

        # Update each atom's position to the averaged position
        for m in range(conf2.GetNumAtoms()):
            x, y, z = average_pos[m]
            conf2.SetAtomPosition(m, Point3D(x, y, z))

        #
        for j in range(10):
            rmsd = AllChem.CalcRMS(group["Molecule"].iloc[j], mol2)
            RMSD_group.append(rmsd)

        mean_RMSD = np.mean(RMSD_group)
        mean_RMSD_tot.append(mean_RMSD)

    # Dataframe formatting

    # Save only the first pose (best score) for each compound, add average RMSD column
    sdf_frame2 = pd.DataFrame(sdf_frame.loc[sdf_frame["Pose Index"] == str(1)]) # Conformer sdf dataframe
    sdf_frame2["Average RMSD"] = mean_RMSD_tot

    score_frame2 = pd.DataFrame(score_frame.loc[score_frame["Pose"] == 0]) # Docking scores dataframe
    score_frame2["Average RMSD"] = mean_RMSD_tot


    # Saving

    # Save updated .sdf file
    #sdf_frame2 = sdf_frame2[['FRED Chemgauss4 score','CG3:Steric','CG3:Clash','CG3:ProDesolv','CG3:LigDesolv','CG3:LigDesolvHB','CG4:HB','Pose Index','ID','SMILES','Molecule', 'Average RMSD']]

    PandasTools.WriteSDF(sdf_frame2, where_to_save + "C" + str(n+1) + "_Top_dockHD_avrgRMSD.sdf",molColName='Molecule',
                         properties=['FRED Chemgauss4 score','CG3:Steric','CG3:Clash','CG3:ProDesolv','CG3:LigDesolv','CG3:LigDesolvHB','CG4:HB','Pose Index'], idName="ID")

    # Save updated score file
    score_frame2.to_csv(where_to_save + "C" + str(n+1) + "_Top_dockHD_score_avrgRMSD.txt", index=False)

# %% [markdown]
# rdkit.Chem.PandasTools.WriteSDF(df, out, molColName='ROMol', idName=None, properties=None, allNumeric=False, forceV3000=False)
#
# Write an SD file for the molecules in the dataframe. Dataframe columns can be exported as SDF tags if specified in the “properties” list. “properties=list(df.columns)” would export all columns. The “allNumeric” flag allows to automatically include all numeric columns in the output. User has to make sure that correct data type is assigned to column. “idName” can be used to select a column to serve as molecule title. It can be set to “RowID” to use the dataframe row key as title.
